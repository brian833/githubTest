# %%
1.#Importing dependancies (libraries)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
2.#Loading datasets

# %%
df = pd.read_csv(r"C:\Git_respiratory\Airbnb_EDA_python_project\New_york_airbn_listing_2024.csv.csv", encoding_errors ='ignore')

# %%
3.#Data exploration

# %%
df.head()
# Out:
#              id                                               name    host_id  \
# 0  1.312228e+06         Rental unit in Brooklyn · ★5.0 · 1 bedroom    7130382
# 1  4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...   51501835
# 2  9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...  528871354
# 3  3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...   19902271
# 4  4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...   61391963
#
#             host_name neighbourhood_group       neighbourhood   latitude  \
# 0              Walter            Brooklyn        Clinton Hill  40.683710
# 1            Jeniffer           Manhattan      Hell's Kitchen  40.766610
# 2              Joshua           Manhattan             Chelsea  40.750764
# 3  John And Catherine           Manhattan  Washington Heights  40.835600
# 4      Stay With Vibe           Manhattan         Murray Hill  40.751120
#
# ...

# %%
df.shape
# Out:
# (20770, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20770 entries, 0 to 20769
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20770 non-null  float64
#  1   name                            20770 non-null  object
#  2   host_id                         20770 non-null  int64
#  3   host_name                       20770 non-null  object
#  4   neighbourhood_group             20770 non-null  object
#  5   neighbourhood                   20763 non-null  object
#  6   latitude                        20763 non-null  float64
#  7   longitude                       20763 non-null  float64
#  8   room_type                       20763 non-null  object
#  9   price                           20736 non-null  float64
#  10  minimum_nights                  20763 non-null  float64
#  11  number_of_reviews               20763 non-null  float64
# ...

# %%
# statistical summary
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  2.063600e+04  2.063600e+04  20636.000000  20636.000000  20636.000000
# mean   3.042603e+17  1.751837e+08     40.726792    -73.939033    165.289252
# std    3.903439e+17  1.726280e+08      0.060379      0.061456    147.139696
# min    2.595000e+03  1.678000e+03     40.500314    -74.249840     10.000000
# 25%    2.720867e+07  2.044685e+07     40.684126    -73.980614     80.000000
# 50%    4.999441e+07  1.093604e+08     40.722730    -73.949490    125.000000
# 75%    7.222500e+17  3.145335e+08     40.763171    -73.917315    199.000000
# max    1.050000e+18  5.504035e+08     40.911147    -73.713650   1499.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20636.000000       20636.000000       20636.000000
# mean        28.580103          42.670721           1.260605
# std         33.614895          73.597800           1.907277
# ...

# %%
#Data cleaning

df.isnull().sum()

#Dropping missing values

df.dropna(inplace = True)

df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# rating                            0
# bedrooms                          0
# beds                              0
# baths                             0
# dtype: int64

# %%
df.shape
# Out:
# (20736, 22)

# %%
#Duplicate rows

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Checking Duplicate values 

df[df.duplicated()]

#Deleting duplicate records

df.drop_duplicates(inplace = True)

df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm, license, rating, bedrooms, beds, baths, price per bed]
# Index: []
#
# [0 rows x 23 columns]

# %%
#Checking data types 

df.dtypes
#Change id dtype to 'object'

df['id'] = df['id'].astype(object)
df['host_id'] = df['host_id'].astype(object)
df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %%
#Data analysis

#univariate analysis
#price distribution

df['price']

sns.histplot(data = df, x = 'price')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
#Identifying outliers

sns.boxplot(data = df, x = 'price')
# Out:
# <Axes: xlabel='price'>

# %%
df = df[df['price'] <1500]

sns.boxplot(data = df, x = 'price')
# Out:
# <Axes: xlabel='price'>

# %%
#Price Distribution

plt.figure(figsize = (8,5))
sns.histplot(data = df, x = 'price', bins = 50)
plt.title('Price Distribution')
plt.ylabel('Frequency')
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %%
#Availability distribution

plt.figure(figsize = (6,3))
sns.histplot(data = df, x = 'availability_365', bins = 50)
plt.title('availability Distribution')
plt.ylabel('Frequency')
plt.show()

# %%
#Average price for bed

df.groupby(by = 'neighbourhood_group')['price per bed'].mean()
# Out:
# neighbourhood_group
# Bronx             74.713639
# Brooklyn          99.788493
# Manhattan        138.662489
# Queens            76.336210
# Staten Island     67.728101
# Name: price per bed, dtype: float64

# %%
df.groupby(by = 'neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx            107.990506
# Brooklyn         155.138317
# Manhattan        204.076470
# Queens           121.681939
# Staten Island    118.780069
# Name: price, dtype: float64

# %%
# Future engineering

df['price per bed'] = df['price']/df['beds']

df.head()
# Out:
#              id                                               name    host_id  \
# 0  1.312228e+06         Rental unit in Brooklyn · ★5.0 · 1 bedroom    7130382
# 1  4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...   51501835
# 2  9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...  528871354
# 3  3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...   19902271
# 4  4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...   61391963
#
#             host_name neighbourhood_group       neighbourhood   latitude  \
# 0              Walter            Brooklyn        Clinton Hill  40.683710
# 1            Jeniffer           Manhattan      Hell's Kitchen  40.766610
# 2              Joshua           Manhattan             Chelsea  40.750764
# 3  John And Catherine           Manhattan  Washington Heights  40.835600
# 4      Stay With Vibe           Manhattan         Murray Hill  40.751120
#
# ...

# %%
#Bi variable analysis
#One variable dependency in another variable

df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths', 'price per bed'],
#       dtype='object')

# %%
sns.barplot(data = df, x ='neighbourhood_group', y = 'price')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
#price dependance on neighbourhood
sns.barplot(data = df, x ='neighbourhood_group', y = 'price', hue = 'room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
#Number of reviews and price rel
sns.scatterplot(data = df, x ='number_of_reviews', y = 'price')
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='price'>

# %%
plt.figure(figsize =(8,5))
sns.scatterplot(data = df, x ='number_of_reviews', y = 'price', hue = 'neighbourhood_group')
plt.title('Locality and review dependency')
plt.show()

# %%
df.dtypes
sns.pairplot(data = df, vars = ['price','minimum_nights','number_of_reviews','availability_365'], hue = 'room_type')

# %%
#Distribution of geographics of Airbnb listing
plt.figure(figsize = (10,7))
sns.scatterplot(data = df, x = 'longitude', y = 'latitude', hue = 'room_type')
plt.title('Geographics Distribution of AirBnb Listing')
plt.show()

# %%
#Heat map - correlation of one variable with others for numerical column
df.dtypes

corr = df[['longitude','latitude','price','minimum_nights','number_of_reviews','reviews_per_month','availability_365','beds']].corr()
corr
# Out:
#                    longitude  latitude     price  minimum_nights  \
# longitude           1.000000  0.047369 -0.193728        0.023890
# latitude            0.047369  1.000000  0.012686        0.004590
# price              -0.193728  0.012686  1.000000       -0.044635
# minimum_nights      0.023890  0.004590 -0.044635        1.000000
# number_of_reviews   0.004820 -0.047953 -0.043533       -0.059049
# reviews_per_month   0.041720 -0.041673 -0.012775       -0.122509
# availability_365    0.063523 -0.005941  0.048036        0.035466
# beds                0.041832 -0.071753  0.415278       -0.025852
#
#                    number_of_reviews  reviews_per_month  availability_365  \
# longitude                   0.004820           0.041720          0.063523
# latitude                   -0.047953          -0.041673         -0.005941
# price                      -0.043533          -0.012775          0.048036
# minimum_nights             -0.059049          -0.122509          0.035466
# ...

# %%
plt.figure(figsize = (8,6))
sns.heatmap(data = corr, annot= True)
plt.show()
